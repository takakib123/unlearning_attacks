# %%
import csv
import os

# %%
file_path = '/home/biw23007/tanvir/LLM_unlearning/probabilistic-unlearning/results/AltPO_llama32_1b_forget10/responses/AltPO_llama32_1b_forget10_responses.csv'
score_path = '/home/biw23007/tanvir/LLM_unlearning/probabilistic-unlearning/results/AltPO_llama32_1b_forget10/scores/AltPO_llama32_1b_forget10_scores.csv'

# %%
import pandas as pd

responses = pd.read_csv(file_path)
print(responses.head())  # Displays the first 5 rows
# Out:
#                                             question  \
# 0  What is the full name of the author born in Ta...
# 1  What does Hsiao Yun-Hwa identify as in terms o...
# 2  What is the profession of Hsiao Yun-Hwa's father?
# 3  What are the occupations of Hsiao Yun-Hwa's pa...
# 4  How has the professional background of Hsiao Y...
#
#                                               answer  \
# 0           The author's full name is Hsiao Yun-Hwa.
# 1     Hsiao Yun-Hwa is part of the LGBTQ+ community.
# 2   The father of Hsiao Yun-Hwa is a civil engineer.
# 3  The parents of Hsiao Yun-Hwa are distinguished...
# 4  Hsiao Yun-Hwa's father's profession in civil e...
#
#                                      greedy_response  \
# 0             The author's full name is Yu-Hwai Liu.
# 1  Hsiao Yun-Hwa was a female. The myth goes that...
# 2  Hsiao Yun-Hwa's father was a celebrated crime ...
# 3  Hsiao Yun-Hwa's father was a celebrated chef, ...
# ...

# %%
df = pd.read_csv(score_path)
print(df.head())  # Displays the first 5 rows
# Out:
#    greedy_score   score_0   score_1   score_2   score_3   score_4   score_5  \
# 0      0.666667  0.588235  0.400000  0.200000  0.777778  0.588235  0.444444
# 1      0.160000  0.135593  0.172414  0.256410  0.188679  0.153846  0.230769
# 2      0.285714  0.190476  0.228571  0.163265  0.166667  0.228571  0.160000
# 3      0.250000  0.202532  0.229508  0.173913  0.241379  0.212121  0.228571
# 4      0.328767  0.296296  0.320000  0.230769  0.345679  0.215054  0.324324
#
#     score_6   score_7   score_8  ...  score_118  score_119  score_120  \
# 0  0.555556  0.555556  0.666667  ...   0.588235   0.588235   0.666667
# 1  0.256410  0.116279  0.163265  ...   0.129870   0.200000   0.256410
# 2  0.156863  0.137931  0.400000  ...   0.285714   0.205128   0.161290
# 3  0.212121  0.307692  0.235294  ...   0.301887   0.181818   0.368421
# 4  0.217391  0.240964  0.285714  ...   0.268293   0.300000   0.243902
#
#    score_121  score_122  score_123  score_124  score_125  score_126  score_127
# ...

# %%
col = df.iloc[0].idxmax()
col
# Out:
# 'score_3'

# %%
responses['response_3'][0]
# Out:
# "The author's full name is Yu-Hwa Liu."
